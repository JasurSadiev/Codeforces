# %% [markdown]
# ![codeforces2.png](data:image/png;base64,...)

# %%
import math
test_case = int(input())
for i in range(test_case):
  x,y = list(map(int, (input().split())))
  if x == 0 and y == 0:
    print(0)
  elif math.sqrt(((0-x)**2 + ((0 - y)**2))).is_integer():
    print(1)
  else:
    print(2)
# Out:
# 3
# 8 6
# 1
# 0 0
# 0
# 9 15
# 2
